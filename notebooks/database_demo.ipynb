# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect(
    dbname="bank_reviews_db",
    user="postgres",
    password="123mahi",
    host="localhost",
    port=5432
)

# Fetch some data
df = pd.read_sql("SELECT * FROM reviews LIMIT 5;", conn)
df.head()

conn.close()
