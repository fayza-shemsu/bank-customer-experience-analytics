# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/reviews_with_sentiment.csv")
df.head()
# Out:
#                               review_id                   review_text  rating  \
# 0  7a0302f8-ef2f-4b7e-919d-d88b0ba6f80a  Easy,fast and more services.       5
# 1  af0e660c-8aa7-4123-b635-3135f036715a                          nice       5
# 2  78f50ee0-6087-4b96-bae1-f1f5a819dfd6                     good bank       5
# 3  a061be6c-9bc4-4ab6-8e46-eb742499eb0e                          good       5
# 4  a905cb2d-0075-4c06-81a1-b91ba37a9bcf                          best       3
#
#   review_date  review_year  review_month   bank_code   bank_name  \
# 0  2025-12-23         2025            12  Amharabank  Amharabank
# 1  2025-12-19         2025            12  Amharabank  Amharabank
# 2  2025-12-14         2025            12  Amharabank  Amharabank
# 3  2025-12-13         2025            12  Amharabank  Amharabank
# 4  2025-12-11         2025            12  Amharabank  Amharabank
#
#              user_name  thumbs_up  text_length       source  vader_compound  \
# ...

# %%
sns.countplot(data=df, x="sentiment")
plt.title("Overall Sentiment Distribution")
plt.show()

# %%
sns.countplot(data=df, x="sentiment", hue="bank_name")
plt.title("Sentiment Distribution by Bank")
plt.show()

# %%
df.groupby("bank_name")["rating"].mean().plot(kind="bar")
plt.title("Average Rating per Bank")
plt.ylabel("Average Rating")
plt.show()

# %%
df["bank_name"].value_counts().plot(kind="bar")
plt.title("Number of Reviews per Bank")
plt.show()
